# %% [markdown]
# # XPPAUT data plots

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from matplotlib.lines import Line2D

matplotlib.rcParams.update({
    'font.family': 'serif',
})

# %%
results1 = np.loadtxt("./data/bifurcation.DAT")

# %%
#plt.scatter(results[:,0], results[:,1])
fig, ax = plt.subplots(1,1,figsize=(7.5,3.5))

colours = np.array(['b', 'r', 'y', 'g','b'])
plt.scatter(results1[:,0], results1[:,1],s=25,c=colours[results1[:,3].astype(int)],marker="1")
plt.scatter(results1[:,0], results1[:,2],s=25,c=colours[results1[:,3].astype(int)],marker="1")

plt.axvline(x=87, lw=1.2, c="black",linestyle=(0, (3, 5, 1, 5)))
plt.axvline(x=217, lw=1.2, c="black",linestyle=(0, (3, 5, 1, 5)))



npzd_legend = [Line2D([0], [0],marker="s", markerfacecolor='r', markersize=10, color='w', lw=4),
               Line2D([0], [0],marker="s", markerfacecolor='y', markersize=10, color='w', lw=4),
               Line2D([0], [0],marker="s", markerfacecolor='g', markersize=10, color='w', lw=4),
               Line2D([0], [0],marker="s", markerfacecolor='b',  markersize=10, color='w', lw=4)]
plt.legend(npzd_legend, ['Stable node', 'Unstable focus', 'Stable limit cycle','Unstable limit cycle'], loc=2, prop={'size': 10})

# Labels
plt.title('Bifurcation diagram')
plt.xlabel('Iapp ($\mu A/cm^2$)')
plt.ylabel('v (mV)')
plt.grid()
plt.tight_layout()

plt.savefig('./img/bifurcation_diagram.pdf')

# %%
results2 = np.loadtxt("./data/frequency.dat")

# %%
results2 = results2[np.where(results2[:,3]!=[1])]
results2 = results2[np.where(results2[:,3]!=[2])]

# %%
#plt.scatter(results[:,0], results[:,1])
fig, ax = plt.subplots(1,1,figsize=(6, 3.5))

colours = np.array(['k', 'r', 'y', 'g','b'])
plt.scatter(results2[:,0], results2[:,1]*1000,s=15,c=colours[results2[:,3].astype(int)],marker="o")
plt.scatter(results2[:,0], results2[:,2]*1000,s=15,c=colours[results2[:,3].astype(int)],marker="o")

plt.axvline(x=87, lw=1.2, c="black",linestyle=(0, (3, 5, 1, 5)))
plt.axvline(x=217, lw=1.2, c="black",linestyle=(0, (3, 5, 1, 5)))



npzd_legend = [Line2D([0], [0],marker="s", markerfacecolor='g', markersize=10, color='w', lw=4),
               Line2D([0], [0],marker="s", markerfacecolor='b',  markersize=10, color='w', lw=4)]
plt.legend(npzd_legend, ['Stable limit cycle','Unstable limit cycle'], loc=2, prop={'size': 10})

plt.ylim([5,25])
plt.xlim([50,250])

# Labels
plt.title('Frequency - Intensity plot')
plt.xlabel('Iapp ($\mu A/cm^2$)')
plt.ylabel('f (Hz)')
plt.grid()
plt.tight_layout()


plt.savefig('./img/fi_plot.pdf')

# %%
results3 = np.loadtxt("./data/2param-bifurcation.dat")

# %%
#plt.scatter(results[:,0], results[:,1])
fig, ax = plt.subplots(1,1,figsize=(6, 3.5))

colours = np.array(['k', 'r', 'y', 'g','b'])
plt.scatter(results3[:,0], results3[:,1],s=15,c=colours[results3[:,3].astype(int)],marker="o")
plt.scatter(results3[:,0], results3[:,2],s=15,c=colours[results3[:,3].astype(int)],marker="o")

#plt.axvline(x=87, lw=1.2, c="black",linestyle=(0, (3, 5, 1, 5)))
#plt.axvline(x=217, lw=1.2, c="black",linestyle=(0, (3, 5, 1, 5)))



npzd_legend = [Line2D([0], [0],marker="s", markerfacecolor='y', markersize=10, color='w', lw=4)]
plt.legend(npzd_legend, ['Hopf bifurcation'], loc=1, prop={'size': 10})



# Labels
plt.title('2 parameter bifurcation diagram')
plt.xlabel('Iapp ($\mu A/cm^2$)')
plt.ylabel('v3 (mV)')
plt.grid()
plt.tight_layout()

plt.savefig('./img/2param_bifurcation.pdf')

# %%
results4 = np.loadtxt("./data/bifurcationsv3.dat")

# %%
#plt.scatter(results[:,0], results[:,1])
fig, ax = plt.subplots(1,1,figsize=(6, 3.5))

colours = np.array(['k', 'r', 'y', 'g','b'])
plt.scatter(results4[:,0], results4[:,1],s=15,c=colours[results4[:,3].astype(int)],marker="1")
plt.scatter(results4[:,0], results4[:,2],s=15,c=colours[results4[:,3].astype(int)],marker="1")

#plt.axvline(x=87, lw=1.2, c="black",linestyle=(0, (3, 5, 1, 5)))
#plt.axvline(x=217, lw=1.2, c="black",linestyle=(0, (3, 5, 1, 5)))



npzd_legend = [Line2D([0], [0],marker="s", markerfacecolor='r', markersize=10, color='w', lw=4),
               Line2D([0], [0],marker="s", markerfacecolor='y', markersize=10, color='w', lw=4),
               Line2D([0], [0],marker="s", markerfacecolor='g', markersize=10, color='w', lw=4),
               Line2D([0], [0],marker="s", markerfacecolor='b',  markersize=10, color='w', lw=4)]
plt.legend(npzd_legend, ['Stable node', 'Unstable focus', 'Stable limit cycle','Unstable limit cycle'], loc=5, prop={'size': 10})


# Labels
plt.title('Bifurcation diagram with v3 = 20mV')
plt.xlabel('Iapp ($\mu A/cm^2$)')
plt.ylabel('V (mV)')
plt.ylim(-60,45)
plt.grid()
plt.tight_layout()

plt.savefig('./img/bifurcation2.pdf')
